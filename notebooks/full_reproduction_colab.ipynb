# %% [markdown]
# # Full Fall Fusion Reproduction
#
# Run this notebook from a Colab session after uploading the repository files or cloning your GitHub repository.

# %%
# !pip -q install pandas numpy scikit-learn scipy matplotlib ultralytics opencv-python-headless

# %% [markdown]
# If you cloned the repo, change into it here. If you uploaded files manually, set `REPO` to that folder.

# %%
import os
REPO = '/content/fall-fusion'  # change this to your repo path
os.chdir(REPO)
print(os.getcwd())

# %%
# !python scripts/ur_event_benchmark.py --data-dir data/urfall --out-dir results/ur_event --bootstrap 2000

# %%
# !python scripts/experiment_stronger_event_models.py --data-dir data/urfall --out-dir results/stronger_event

# %%
# !python scripts/ur_yolo_pose_baseline.py --data-dir data/urfall --video-dir data/urfall_videos --pose-cache results/yolo_pose/pose_features.csv --out-dir results/yolo_pose --imgsz 256

# %%
# !python scripts/ur_full_multimodal_event_forest.py --data-dir data/urfall --pose-cache results/yolo_pose/pose_features.csv --out-dir results/full_multimodal

# %%
# !python scripts/umafall_external_benchmark.py --data-dir data/umafall --out-dir results/umafall

# %%
import pandas as pd
display(pd.read_csv('results/ur_event/ur_event_summary.csv'))
display(pd.read_csv('results/stronger_event/summary.csv'))
display(pd.read_csv('results/yolo_pose/yolo_pose_summary.csv'))
display(pd.read_csv('results/full_multimodal/summary.csv'))
display(pd.read_csv('results/umafall/umafall_summary.csv'))
