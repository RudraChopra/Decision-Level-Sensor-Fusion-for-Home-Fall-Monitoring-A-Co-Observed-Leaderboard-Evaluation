# %% [markdown]
# # UR Fall Event-Level Benchmark Runner
#
# Upload `ur_event_benchmark.py` from the `revision` folder, then run the corrected event-level evaluation.

# %%
# !pip -q install pandas numpy scikit-learn scipy matplotlib

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !python ur_event_benchmark.py --data-dir /content/urfall --out-dir /content/ur_event_results --bootstrap 2000

# %%
import pandas as pd
summary = pd.read_csv('/content/ur_event_results/ur_event_summary.csv')
ci = pd.read_csv('/content/ur_event_results/ur_event_bootstrap_ci.csv')
display(summary[['method','tp','fp_episodes','event_f1','event_precision','event_recall','false_alarms_per_hour','median_latency_s','frame_f1']])
display(ci)

# %%
# !zip -r ur_event_results.zip /content/ur_event_results
files.download('ur_event_results.zip')
